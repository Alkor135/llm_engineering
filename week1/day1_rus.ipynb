# %% [markdown]
# # ТВОЙ ПЕРВЫЙ ЛАБ
# ### Пожалуйста, прочитай этот раздел. Это ценно для подготовки, даже если это долгое чтение – это важная информация.
#
# ## Твой первый проект с LLM в Frontier
#
# Давайте создадим полезное решение на основе LLM — всего за несколько минут.
#
# К концу этого курса ты построишь автономное агентское AI-решение с 7 агентами, которые сотрудничают для решения бизнес-задачи. Но мы начнем с чего-то меньшего...
#
# Наша цель – создать новый вид веб-браузера. Дай ему URL, и он ответит сводкой. Пересказчик интернета!!
#
# Прежде чем начать, ты должен завершить настройку для ПК или Mac и, надеюсь, запустить эту Jupyter Lab из корневой директории проекта с активированной средой.
#
# ## Если ты новичок в Jupyter Lab:
#
# Добро пожаловать в удивительный мир экспериментов по Data Science! Как только ты освоишь Jupyter Lab, тебе будет сложно представить, как ты раньше обходился без него. Просто щелкни в каждой ячейке с кодом, например, в ячейке сразу под этим текстом, и нажми Shift+Return для ее выполнения. По желанию, ты можешь добавить ячейку с помощью кнопки "+" на панели инструментов, распечатать значения переменных или попробовать различные варианты.
#
# Я написал блокнот под названием "Руководство по Jupyter", чтобы помочь тебе лучше освоиться в Jupyter Lab, включая добавление комментариев Markdown, использование ! для запуска команд оболочки и tqdm для отображения прогресса.
#
# ## Если ты новичок в командной строке:
#
# Пожалуйста, ознакомься с этими отличными руководствами: Командная строка на ПК и Командная строка на Mac.
#
# ## Если ты предпочитаешь работать в IDE:
#
# Если тебе комфортнее в IDE, таких как VSCode, Cursor или PyCharm, они отлично работают с этими лабораторными блокнотами тоже.
# Если ты предпочитаешь работать в VSCode [здесь](https://chatgpt.com/share/676f2e19-c228-8012-9911-6ca42f8ed766), вот инструкции от AI-друга о том, как его настроить для курса.
#
# ## Если хочешь освежить свои знания по Python:
#
# Я добавил блокнот под названием "Средний уровень Python", чтобы помочь тебе наверстать упущенное. Но если ты уже хорошо понимаешь, что делает этот код, можешь пропустить его:
# `yield from {book.get("author") for book in books if book.get("author")}`
#
# ## Я здесь, чтобы помочь:
#
# Если у тебя возникнут какие-либо проблемы, пожалуйста, свяжись со мной.
# Я доступен через платформу, или по адресу
# ed@edwarddonner.com, или в LinkedIn
# https://www.linkedin.com/in/eddonner/
#
#  если ты хочешь связаться (и я люблю общаться!)
# И это для меня ново, но я также экспериментирую с X/Twitter @edwarddonner - если ты в X, покажи мне, как это делается 😂
#
# Больше по устранению неполадок:
#
# Пожалуйста, ознакомься с блокнотом "Устранение неполадок" в этой папке для диагностики и исправления распространенных проблем. В конце находится скрипт отладки с полезной информацией для отладки.
#
# ## Для базовых технических знаний (например, Git, API, отладка):
#
# Если ты относительно новичок в программировании – я тебя поддерживаю! Хотя для этого курса желательно иметь некоторый опыт программирования, есть только одно обязательное требование: много терпения. 😁 Я подготовил набор руководств для самостоятельного изучения, охватывающих Git и GitHub, API и конечные точки, начальный уровень Python и многое другое.
#
# Это описывает Git и GitHub; что это такое, в чем разница и как их использовать:
#
# https://github.com/ed-donner/agents/blob/main/guides/03_git_and_github.ipynb
#
#
# Это описывает технические основы:
# ChatGPT vs API; создание скриншотов; Переменные среды; Основы сети; API и конечные точки:
#
# https://github.com/ed-donner/agents/blob/main/guides/04_technical_foundations.ipynb
#
#
# Это описывает Python для начинающих, и гарантирует, что NameError тебя не подставит:
#
# https://github.com/ed-donner/agents/blob/main/guides/06_python_foundations.ipynb
#
#
# Это описывает основные методы выявления ошибок:
#
# https://github.com/ed-donner/agents/blob/main/guides/08_debugging.ipynb
#
#
# И ты найдешь другие полезные руководства в той же папке на GitHub. Некоторые сведения применимы к моему другому курсу Udemy (например, Async Python), но большая часть из них очень актуальна для LLM-инженерии.
#
# Если это уже знакомо!
#
# Если ты уже знаком с сегодняшним материалом, пожалуйста, не торопись; ты можешь быстро пройти первые несколько лабораторных работ – мы углубимся по мере того, как недели будут проходить. В конечном итоге мы будем дорабатывать собственную LLM, чтобы конкурировать с OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Пожалуйста, прочитайте – важное примечание.</h2>
#             <span style="color:#900;">Мой способ взаимодействия с тобой может отличаться от того, как ты взаимодействовал в других курсах. Я предпочитаю не печатать код, пока ты смотришь. Вместо этого я запускаю Jupyter Labs, как это сделано здесь, и даю понимание происходящего. Мое предложение заключается в том, чтобы ты внимательно выполнил это сам после просмотра лекции. Добавь операторы print для понимания того, что происходит, а затем придумай свои собственные варианты. Если у тебя есть аккаунт на Github, используй его для демонстрации своих вариаций. Это не только важная практика, но и демонстрирует твои навыки другим, включая потенциальных клиентов или работодателей...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Этот код — живой ресурс — следите за моими письмами.</h2>
#             <span style="color:#f71;">Я регулярно обновляю код. Когда люди задают вопросы, я добавляю больше примеров или улучшенные комментарии. В результате вы можете заметить, что код ниже не идентичен видео. Здесь есть все из видео; но также добавлены лучшие объяснения и новые модели, такие как DeepSeek. Рассматривайте это как интерактивную книгу.
#
# Я стараюсь регулярно отправлять обновления по электронной почте, связанные с курсом. Вы можете найти их в разделе «Объявления» на Udemy в левой боковой панели. Вы также можете выбрать получение моих писем через настройки уведомлений в Udemy. Я уважаю вашу папку входящих и всегда стараюсь добавить ценности своими письмами!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Бизнес-ценность этих упражнений.</h2>
#             <span style="color:#181;">В заключение. Хотя я разработал эти блокноты с образовательной целью, я также постарался сделать их увлекательными. Мы будем делать забавные вещи, например, просить LLM рассказывать анекдоты и спорить друг с другом. Но в основе своей моя цель – научить навыкам, которые можно применять в бизнесе. Я буду объяснять бизнес-последствия по ходу дела, и важно помнить об этом: по мере приобретения опыта работы с моделями и техниками думайте о том, как вы можете применить это на практике уже сегодня. Пожалуйста, свяжитесь со мной, если хотите обсудить что-то еще или у вас есть идеи, которые нужно обсудить.</span>
#         </td>
#     </tr>
# </table>
