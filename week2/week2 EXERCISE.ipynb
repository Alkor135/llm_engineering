# %% [markdown]
# # Дополнительное упражнение в конце недели - неделя 2
#
# Теперь используйте все, что вы узнали на второй неделе, для создания полноценного прототипа технического вопроса / ответа, который вы разработали в упражнении недели 1.
#
# Это должно включать в себя пользовательский интерфейс радио, потоковое вещание, использование системных подсказок для повышения квалификации и возможность переключения между моделями. Бонусные баллы, если вы сможете продемонстрировать использование инструмента!
#
# Если вы наберетесь смелости, посмотрите, можно ли добавить аудиовход, чтобы вы могли разговаривать с ним, и чтобы он отвечал с помощью звука. ChatGPT или Claude могут вам помочь, или напишите мне, если у вас возникнут вопросы.
#
# Скоро я опубликую здесь полное решение - если только кто-нибудь не опередит меня...
#
# Для этого есть множество коммерческих приложений: от репетитора по языку до решения для внедрения в компании, от вспомогательного искусственного интеллекта до курсов (подобных этому!) Мне не терпится увидеть ваши результаты.
